# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
n = 3000000
L = 100  #System is of size LxL with the origin at the center. The units of L are of 1/s
T = 10 # the systhem is initialized at room temperature
#init_pos = np.array([[0, 0, 0],[L-1, L-1, L-1], [847, 325, 638], [748, 475, 224], [448, 45, 834], [97, 145, 564]])
#init_pos = np.random.uniform(low = 0, high = 1000, size = (n,3))
init_vel = np.random.normal(np.sqrt(T/119.8), size = (n, 3))
init_vel = init_vel - np.mean(init_vel, axis=0)
time_step = float(1e-4)
a = L/10

#number_of_steps = 2000         #strange that verlet and euler give exact same result...
number_of_steps = int(10000)       # here we see verlet doesn't let the energy diverge. still oscillates
times = np.arange(0,(number_of_steps + 1) * time_step, time_step)
dimensions = 3

# %%
run -i skeleton.py

# %% [markdown]
# (L/a)^3 is the number of cells in the LxLxL box. That times 4 gives the theoretical maximum of particles.

# %%
init_pos = fcc_lattice(a)
#print(init_pos)
max_n = int((L/a)**3 * 4)            #Theoretical maximum of particles
print ("theoretical maximum:", max_n)

x = init_pos[:,0]
y = init_pos[:,1]
z = init_pos[:,2]
n = len(init_pos)
print("you have", n, "particles")
r = atomic_distances(init_pos, 0)
#print(r+np.identity(len(r)))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x,y,z)
plt.show()
# Out:
# theoretical maximum: 4000
# you have 4000 particles
