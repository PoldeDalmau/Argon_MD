# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 3                                                              #number of particles
L = 1000                                                           #System is of size LxLxL with the origin at (0,0,0). The units of L are of 1/sigma
init_pos = np.array([[0, 0, 0],[L-1, L-1, L-1], [1, 1, 1]])
init_vel = np.zeros((n, 3))
time_step = float(1e-3)
number_of_steps = int(10000)                                       # here we see verlet doesn't let the energy diverge. still oscillates
times = np.arange(0,(number_of_steps + 1) * time_step, time_step)

# %%
run -i skeleton.py
# Out:
# using Euler:
# using Verlet:
